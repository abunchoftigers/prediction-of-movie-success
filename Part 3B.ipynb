# %%
import os
import numpy as np
import pandas as pd
from sqlalchemy import create_engine
os.makedirs('Data/', exist_ok=True)

# %%
import glob
# Use glob to get all filepaths that match the pattern (*=wildcard)
tmdb_files = sorted(glob.glob("Data/final_tmdb_data*.csv.gz"))
tmdb_files
# Out:
# ['Data\\final_tmdb_data_2002.csv.gz', 'Data\\final_tmdb_data_combined.csv.gz']

# %%
# Use read_csv in a list comprehension and combine with concat to load all files
tmdb = pd.concat([pd.read_csv(f) for f in tmdb_files] )
tmdb
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0096056    0.0  /95U3MUDXu4xSCmVLtWgargRipDi.jpg
# 2     tt0118926    0.0  /qR3Dk3ctnrrxkAI6I472RhamIbu.jpg
# 3     tt0119980    0.0                               NaN
# 4     tt0120679    0.0  /s04Ds4xbJU7DzeGVyamccH4LoxF.jpg
# ...         ...    ...                               ...
# 1389  tt6801910    0.0                               NaN
# 1390  tt7758748    0.0                               NaN
# 1391  tt8302928    0.0                               NaN
# 1392  tt8474326    0.0                               NaN
# 1393  tt8825252    0.0                               NaN
#
#      belongs_to_collection      budget  \
# 0                      NaN         NaN
# 1                      NaN         0.0
# 2                      NaN         0.0
# 3                      NaN         0.0
# 4                      NaN  12000000.0
# ...                    ...         ...
# 1389                   NaN         0.0
# 1390                   NaN         0.0
# 1391                   NaN         0.0
# 1392                   NaN         0.0
# 1393                   NaN         0.0
#
#                                                  genres  \
# 0                                                   NaN
# 1                         [{'id': 18, 'name': 'Drama'}]
# 2     [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 3     [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 4     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# ...                                                 ...
# 1389  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 1390  [{'id': 18, 'name': 'Drama'}, {'id': 9648, 'na...
# 1391  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 1392                                                 []
# 1393                    [{'id': 14, 'name': 'Fantasy'}]
#
#                                                homepage         id  \
# 0                                                   NaN        NaN
# 1                                                   NaN   109809.0
# 2                                                   NaN    20689.0
# 3                                                   NaN   563364.0
# 4                   https://www.miramax.com/movie/frida     1360.0
# ...                                                 ...        ...
# 1389                                                NaN   339829.0
# 1390  https://www.imvbox.com/en/movies/look-at-me-be...  1045181.0
# 1391                                                NaN   866533.0
# 1392                                                NaN   292027.0
# 1393                                                NaN   989195.0
#
#      original_language                        original_title  ...     revenue  \
# 0                  NaN                                   NaN  ...         NaN
# 1                   en                  Crime and Punishment  ...         0.0
# 2                   en                   The Dancer Upstairs  ...   5227348.0
# 3                   en                 Random Shooting in LA  ...         0.0
# 4                   en                                 Frida  ...  56298474.0
# ...                ...                                   ...  ...         ...
# 1389                ta                                 தமிழ்  ...         0.0
# 1390                fa                         به من نگاه کن  ...         0.0
# 1391                el          Movie Toons: Treasure Island  ...         0.0
# 1392                en           Skin Eating Jungle Vampires  ...         0.0
# 1393                en  Circle of Fire: The Dark Lord Kylnor  ...         0.0
#
#       runtime                                   spoken_languages    status  \
# 0         NaN                                                NaN       NaN
# 1       126.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2       132.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3        91.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4       123.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# ...       ...                                                ...       ...
# 1389    145.0  [{'english_name': 'Tamil', 'iso_639_1': 'ta', ...  Released
# 1390    122.0  [{'english_name': 'Persian', 'iso_639_1': 'fa'...  Released
# 1391      0.0                                                 []  Released
# 1392      0.0                                                 []  Released
# 1393     45.0                                                 []  Released
#
#                                                 tagline  \
# 0                                                   NaN
# 1                                                   NaN
# 2     An honest man caught in a world of intrigue, p...
# 3                                                   NaN
# 4                                Prepare to be seduced.
# ...                                                 ...
# 1389                                                NaN
# 1390                           Director: Shahram Assadi
# 1391                                                NaN
# 1392                                                NaN
# 1393                                                NaN
#
#                                      title  video  vote_average vote_count  \
# 0                                      NaN    NaN           NaN        NaN
# 1                     Crime and Punishment    0.0         5.400       13.0
# 2                      The Dancer Upstairs    0.0         6.200       51.0
# 3                    Random Shooting in LA    0.0         0.000        0.0
# 4                                    Frida    0.0         7.422     1918.0
# ...                                    ...    ...           ...        ...
# 1389                               Thamizh    0.0         6.000        1.0
# 1390                       Look at Me 2002    0.0         0.000        0.0
# 1391          Movie Toons: Treasure Island    0.0         0.000        0.0
# 1392           Skin Eating Jungle Vampires    0.0         0.000        0.0
# 1393  Circle of Fire: The Dark Lord Kylnor    0.0         0.000        0.0
#
#      certification
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4                R
# ...            ...
# 1389           NaN
# 1390           NaN
# 1391           NaN
# 1392           NaN
# 1393           NaN
#
# [2788 rows x 26 columns]

# %%
basics_url = "C:/Users/dsdye/Documents/GitHub/prediction-of-movie-success/Data/basics.csv"

basics = pd.read_csv(basics_url, low_memory=False)

# %%
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El tango del viudo y su espejo deformante        0       2020      NaN
# 2                 The Other Side of the Wind        0       2018      NaN
# 3                          The Naked Monster        0       2005      NaN
# 4                       Crime and Punishment        0       2002      NaN
#
#    runtime                  genres
# 0    118.0  Comedy,Fantasy,Romance
# 1     70.0                   Drama
# 2    122.0                   Drama
# 3    100.0    Comedy,Horror,Sci-Fi
# 4    126.0                   Drama

# %%
basics.shape
# Out:
# (104636, 9)

# %%
# Create the sqlalchemy engine and connection
username = "root"
password = "root"
db_name = "movies"
connection = f"mysql+pymysql://{username}:{password}@localhost/{db_name}"
engine = create_engine(connection)
conn = engine.connect()

# %%
q = '''SHOW TABLES;'''
pd.read_sql(q, conn)
# Out:
#   Tables_in_movies
# 0           genres
# 1          ratings
# 2     title_basics
# 3     title_genres
# 4        tmdb_data

# %%
basics = basics[basics['genres'].notna()]

# %%
## create a col with a list of genres
basics['genres_split'] = basics['genres'].str.split(',')
basics
# Out:
#            tconst titleType  \
# 0       tt0035423     movie
# 1       tt0062336     movie
# 2       tt0069049     movie
# 3       tt0088751     movie
# 4       tt0096056     movie
# ...           ...       ...
# 104631  tt9915872     movie
# 104632  tt9916170     movie
# 104633  tt9916190     movie
# 104634  tt9916362     movie
# 104635  tt9916428     movie
#
#                                              primaryTitle  \
# 0                                          Kate & Leopold
# 1       The Tango of the Widower and Its Distorting Mi...
# 2                              The Other Side of the Wind
# 3                                       The Naked Monster
# 4                                    Crime and Punishment
# ...                                                   ...
# 104631                               The Last White Witch
# 104632                                      The Rehearsal
# 104633                                          Safeguard
# 104634                                              Coven
# 104635                                The Secret of China
#
#                                     originalTitle  isAdult  startYear  \
# 0                                  Kate & Leopold        0       2001
# 1       El tango del viudo y su espejo deformante        0       2020
# 2                      The Other Side of the Wind        0       2018
# 3                               The Naked Monster        0       2005
# 4                            Crime and Punishment        0       2002
# ...                                           ...      ...        ...
# 104631                  My Girlfriend is a Wizard        0       2019
# 104632                                   O Ensaio        0       2019
# 104633                                  Safeguard        0       2020
# 104634                                   Akelarre        0       2020
# 104635               Hong xing zhao yao Zhong guo        0       2019
#
#         endYear  runtime                     genres  \
# 0           NaN    118.0     Comedy,Fantasy,Romance
# 1           NaN     70.0                      Drama
# 2           NaN    122.0                      Drama
# 3           NaN    100.0       Comedy,Horror,Sci-Fi
# 4           NaN    126.0                      Drama
# ...         ...      ...                        ...
# 104631      NaN     97.0       Comedy,Drama,Fantasy
# 104632      NaN     51.0                      Drama
# 104633      NaN     95.0  Action,Adventure,Thriller
# 104634      NaN     92.0              Drama,History
# 104635      NaN      NaN      Adventure,History,War
#
#                          genres_split
# 0          [Comedy, Fantasy, Romance]
# 1                             [Drama]
# 2                             [Drama]
# 3            [Comedy, Horror, Sci-Fi]
# 4                             [Drama]
# ...                               ...
# 104631       [Comedy, Drama, Fantasy]
# 104632                        [Drama]
# 104633  [Action, Adventure, Thriller]
# 104634               [Drama, History]
# 104635      [Adventure, History, War]
#
# [101501 rows x 10 columns]

# %%
exploded_genres = basics.explode('genres_split')
exploded_genres
# Out:
#            tconst titleType  \
# 0       tt0035423     movie
# 0       tt0035423     movie
# 0       tt0035423     movie
# 1       tt0062336     movie
# 2       tt0069049     movie
# ...           ...       ...
# 104634  tt9916362     movie
# 104634  tt9916362     movie
# 104635  tt9916428     movie
# 104635  tt9916428     movie
# 104635  tt9916428     movie
#
#                                              primaryTitle  \
# 0                                          Kate & Leopold
# 0                                          Kate & Leopold
# 0                                          Kate & Leopold
# 1       The Tango of the Widower and Its Distorting Mi...
# 2                              The Other Side of the Wind
# ...                                                   ...
# 104634                                              Coven
# 104634                                              Coven
# 104635                                The Secret of China
# 104635                                The Secret of China
# 104635                                The Secret of China
#
#                                     originalTitle  isAdult  startYear  \
# 0                                  Kate & Leopold        0       2001
# 0                                  Kate & Leopold        0       2001
# 0                                  Kate & Leopold        0       2001
# 1       El tango del viudo y su espejo deformante        0       2020
# 2                      The Other Side of the Wind        0       2018
# ...                                           ...      ...        ...
# 104634                                   Akelarre        0       2020
# 104634                                   Akelarre        0       2020
# 104635               Hong xing zhao yao Zhong guo        0       2019
# 104635               Hong xing zhao yao Zhong guo        0       2019
# 104635               Hong xing zhao yao Zhong guo        0       2019
#
#         endYear  runtime                  genres genres_split
# 0           NaN    118.0  Comedy,Fantasy,Romance       Comedy
# 0           NaN    118.0  Comedy,Fantasy,Romance      Fantasy
# 0           NaN    118.0  Comedy,Fantasy,Romance      Romance
# 1           NaN     70.0                   Drama        Drama
# 2           NaN    122.0                   Drama        Drama
# ...         ...      ...                     ...          ...
# 104634      NaN     92.0           Drama,History        Drama
# 104634      NaN     92.0           Drama,History      History
# 104635      NaN      NaN   Adventure,History,War    Adventure
# 104635      NaN      NaN   Adventure,History,War      History
# 104635      NaN      NaN   Adventure,History,War          War
#
# [181605 rows x 10 columns]

# %%
unique_genres = sorted(exploded_genres['genres_split'].unique())
unique_genres
# Out:
# ['Action',
#  'Adult',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Game-Show',
#  'History',
#  'Horror',
#  'Music',
#  'Musical',
#  'Mystery',
#  'News',
#  'Reality-TV',
#  'Romance',
#  'Sci-Fi',
#  'Sport',
#  'Talk-Show',
#  'Thriller',
#  'War',
#  'Western']

# %%
title_genres = exploded_genres[['tconst','genres_split']].copy()
title_genres.head()
# Out:
#       tconst genres_split
# 0  tt0035423       Comedy
# 0  tt0035423      Fantasy
# 0  tt0035423      Romance
# 1  tt0062336        Drama
# 2  tt0069049        Drama

# %%
## Making the genre mapper dictionary
genre_ints = range(len(unique_genres))
genre_map = dict(zip(unique_genres, genre_ints))
genre_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Sport': 20,
#  'Talk-Show': 21,
#  'Thriller': 22,
#  'War': 23,
#  'Western': 24}

# %%
exploded_genres.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 0  tt0035423     movie                                     Kate & Leopold
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 0                             Kate & Leopold        0       2001      NaN
# 0                             Kate & Leopold        0       2001      NaN
# 1  El tango del viudo y su espejo deformante        0       2020      NaN
# 2                 The Other Side of the Wind        0       2018      NaN
#
#    runtime                  genres genres_split
# 0    118.0  Comedy,Fantasy,Romance       Comedy
# 0    118.0  Comedy,Fantasy,Romance      Fantasy
# 0    118.0  Comedy,Fantasy,Romance      Romance
# 1     70.0                   Drama        Drama
# 2    122.0                   Drama        Drama

# %%
basics = exploded_genres

# %%
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 0  tt0035423     movie                                     Kate & Leopold
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 0                             Kate & Leopold        0       2001      NaN
# 0                             Kate & Leopold        0       2001      NaN
# 1  El tango del viudo y su espejo deformante        0       2020      NaN
# 2                 The Other Side of the Wind        0       2018      NaN
#
#    runtime                  genres genres_split
# 0    118.0  Comedy,Fantasy,Romance       Comedy
# 0    118.0  Comedy,Fantasy,Romance      Fantasy
# 0    118.0  Comedy,Fantasy,Romance      Romance
# 1     70.0                   Drama        Drama
# 2    122.0                   Drama        Drama

# %%
## make new integer genre_id and drop string genres
basics['genre_id'] = basics['genres_split'].map(genre_map)
basics = basics.drop(columns='genres_split')

# %%
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 0  tt0035423     movie                                     Kate & Leopold
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 0                             Kate & Leopold        0       2001      NaN
# 0                             Kate & Leopold        0       2001      NaN
# 1  El tango del viudo y su espejo deformante        0       2020      NaN
# 2                 The Other Side of the Wind        0       2018      NaN
#
#    runtime                  genres  genre_id
# 0    118.0  Comedy,Fantasy,Romance         5
# 0    118.0  Comedy,Fantasy,Romance         9
# 0    118.0  Comedy,Fantasy,Romance        18
# 1     70.0                   Drama         7
# 2    122.0                   Drama         7

# %%
genre_lookup = pd.DataFrame({'Genre_Name': genre_map.keys(),
                            'Genre_ID': genre_map.values()})

# %%
genre_lookup
# Out:
#     Genre_Name  Genre_ID
# 0       Action         0
# 1        Adult         1
# 2    Adventure         2
# 3    Animation         3
# 4    Biography         4
# 5       Comedy         5
# 6        Crime         6
# 7        Drama         7
# 8       Family         8
# 9      Fantasy         9
# 10   Game-Show        10
# 11     History        11
# 12      Horror        12
# 13       Music        13
# 14     Musical        14
# 15     Mystery        15
# 16        News        16
# 17  Reality-TV        17
# 18     Romance        18
# 19      Sci-Fi        19
# 20       Sport        20
# 21   Talk-Show        21
# 22    Thriller        22
# 23         War        23
# 24     Western        24

# %%
genre_lookup.to_sql('genres', engine, if_exists='replace')
# Out:
# 25

# %%
basics.dtypes
# Out:
# tconst            object
# titleType         object
# primaryTitle      object
# originalTitle     object
# isAdult            int64
# startYear          int64
# endYear          float64
# runtime          float64
# genres            object
# genre_id           int64
# dtype: object

# %%
q = '''SHOW TABLES;'''
pd.read_sql(q, conn)
# Out:
#   Tables_in_movies
# 0           genres
# 1          ratings
# 2     title_basics
# 3     title_genres
# 4        tmdb_data

# %%
## Example
from sqlalchemy.types import *
## Calculate max string lengths for object columns
key_len = tmdb['imdb_id'].fillna('').map(len).max()
cert_len = 6
## Create a schema dictonary using Sqlalchemy datatype objects
df_schema = {
    "imdb_id": CHAR(key_len+1), 
    "budget": FLOAT(),
    "revenue": FLOAT(),
    'certification':CHAR(key_len+1)}

# %%
# Save to sql with dtype and index=False
tmdb.to_sql('tmdb_data',conn, dtype=df_schema, if_exists='replace',index=False)
# Out:
# 2788

# %%
engine.execute('ALTER TABLE tmdb_data ADD PRIMARY KEY (`imdb_id`);')

# %%
q = '''DESCRIBE tmdb_data;'''
pd.read_sql(q, conn)
# Out:
#                     Field      Type Null Key Default Extra
# 0                 imdb_id  char(11)  YES        None
# 1                   adult    double  YES        None
# 2           backdrop_path      text  YES        None
# 3   belongs_to_collection      text  YES        None
# 4                  budget     float  YES        None
# 5                  genres      text  YES        None
# 6                homepage      text  YES        None
# 7                      id    double  YES        None
# 8       original_language      text  YES        None
# 9          original_title      text  YES        None
# 10               overview      text  YES        None
# 11             popularity    double  YES        None
# 12            poster_path      text  YES        None
# 13   production_companies      text  YES        None
# 14   production_countries      text  YES        None
# 15           release_date      text  YES        None
# 16                revenue     float  YES        None
# 17                runtime    double  YES        None
# 18       spoken_languages      text  YES        None
# 19                 status      text  YES        None
# 20                tagline      text  YES        None
# 21                  title      text  YES        None
# 22                  video    double  YES        None
# 23           vote_average    double  YES        None
# 24             vote_count    double  YES        None
# 25          certification  char(11)  YES        None

# %%
q = '''SHOW TABLES;'''
pd.read_sql(q, conn)
